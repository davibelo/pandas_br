# %%
import pandas as pd
import os

# %%
path = os.getcwd() + "/"
print(path)
# Out:
# /home/davibelo/Desktop/pandas_br/04-Selecionando do Dataframe/

# %%
dados = pd.read_excel(path + "Dados.xlsx")
dados.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM          0   NaN       Ken          J
# 1                 2         EM          0   NaN     Terri        Lee
# 2                 3         EM          0   NaN   Roberto        NaN
# 3                 4         EM          0   NaN       Rob        NaN
# 4                 5         EM          0   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion
# 0     Sánchez    NaN               0
# 1       Duffy    NaN               1
# 2  Tamburello    NaN               0
# 3     Walters    NaN               0
# 4    Erickson    NaN               0

# %%
# Selecionando uma coluna por nome da coluna
dados["MiddleName"].head()
# Out:
# 0      J
# 1    Lee
# 2    NaN
# 3    NaN
# 4      A
# Name: MiddleName, dtype: object

# %%
# Selecionando mais colunas (passar uma lista de nomes de colunas como argumento)
dados[["FirstName", "MiddleName"]].head()
# Out:
#   FirstName MiddleName
# 0       Ken          J
# 1     Terri        Lee
# 2   Roberto        NaN
# 3       Rob        NaN
# 4      Gail          A

# %%
# Selecionado coluna por notação de ponto
dados.MiddleName.head()
# Out:
# 0      J
# 1    Lee
# 2    NaN
# 3    NaN
# 4      A
# Name: MiddleName, dtype: object

# %%
# Filtrando dataframe por conteúdo da coluna
dados_filtrados = dados[dados["FirstName"] == "Robert"]
dados_filtrados.head()
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 189               190         EM          0   NaN    Robert          J
# 302               315         SC          0   Mr.    Robert         E.
# 334               379         SC          0   Mr.    Robert         A.
# 347               405         SC          0   Mr.    Robert         L.
# 380               471         SC          0   Mr.    Robert         M.
#
#         LastName Suffix  EmailPromotion
# 189  Rounthwaite    NaN               0
# 302     Ahlering    NaN               0
# 334       Avalos    NaN               0
# 347       Barker    NaN               0
# 380    Bernacchi    NaN               1

# %%
# Filtrando dataframe por conteúdo da coluna 2
dados_filtrados = dados[dados["FirstName"].str.contains("Rob")]
dados_filtrados.head()

# OBS: dados["FirstName"] retorna uma panda series
# panda series tem esse método str.contais que filtra conteúdo de strings
# dados[<filtro>] retorna o pandas dataframe filtrado pelo conteúdo do que está no <filtro>
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 2                   3         EM          0   NaN   Roberto        NaN
# 3                   4         EM          0   NaN       Rob        NaN
# 129               130         EM          0   NaN       Rob          T
# 189               190         EM          0   NaN    Robert          J
# 302               315         SC          0   Mr.    Robert         E.
#
#         LastName Suffix  EmailPromotion
# 2     Tamburello    NaN               0
# 3        Walters    NaN               0
# 129        Caron    NaN               0
# 189  Rounthwaite    NaN               0
# 302     Ahlering    NaN               0

# %%
# Adicionando coluna nova
dados["nome_completo"] = dados["FirstName"] + " " + dados["LastName"]
dados.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM          0   NaN       Ken          J
# 1                 2         EM          0   NaN     Terri        Lee
# 2                 3         EM          0   NaN   Roberto        NaN
# 3                 4         EM          0   NaN       Rob        NaN
# 4                 5         EM          0   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion       nome_completo
# 0     Sánchez    NaN               0         Ken Sánchez
# 1       Duffy    NaN               1         Terri Duffy
# 2  Tamburello    NaN               0  Roberto Tamburello
# 3     Walters    NaN               0         Rob Walters
# 4    Erickson    NaN               0       Gail Erickson
